# %%
import matplotlib.pyplot as plt
from utils.logger import load_log

# %%
log = load_log("experiments/20-12-14_bernoulli_a2c/logs/20-12-14_bernoulli_a2c_.hdf5")

# %%
log.keys()
# Out:
# dict_keys(['actor_loss', 'critic_loss', 'entropy_loss', 'ep_regret', 'ep_reward', 'ep_subopt_pulls', 'num_episodes', 'num_steps', 'time_elapsed', 'total_loss'])

# %%
plt.plot(log.num_episodes, log.ep_regret)
plt.xlabel("Train Episodes")
plt.ylabel("Mean Episode Regret")
plt.title("Easy Bernoulli Bandit")
# Out:
# Text(0.5, 1.0, 'Easy Bernoulli Bandit')
